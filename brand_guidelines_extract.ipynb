# %% [markdown]
# # Review Scoop Room Brand Guideline
# This notebook is used to inspect the Scoop Room brand guideline PDF and then update the About section of the project to match the brand's typography, colors, spacing, and messaging.

# %%
from pypdf import PdfReader
reader = PdfReader(r'c:\Users\finan\OneDrive\AppData\Scoop Room\public\Scoop Room Brand Guidelines (9).pdf')
print('pages:', len(reader.pages))
for i, page in enumerate(reader.pages[:4]):
    text = page.extract_text() or ''
    print(f'--- PAGE {i+1} ---')
    print(text[:2000])
    print()
